# %% [markdown]
# ```
# # Documentacion
# https://estadisticasbcra.com/api/documentacion
# ```

# %%
import requests
import pandas as pd
import json

# %%
url = 'https://api.estadisticasbcra.com/'

# %%
token = 'eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCJ9.eyJleHAiOjE3MTkzNTU0NjYsInR5cGUiOiJleHRlcm5hbCIsInVzZXIiOiJwZXBlbHVpMTk4NUBnbWFpbC5jb20ifQ.gQpwTzclGcm8-6KoAB7GdcC9QeNpZV20Q_6ExzdHB_bRI-kMAK93FGOGC8INaxkovjY7Ol_cZzF1YcDp5n-JHg'
data= requests.get(url + 'prestamos', headers={'Authorization': 'Bearer {}'.format(token)}).json()

# %%
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#             d      v
# 0  1996-04-01  47165
# 1  1996-04-02  47119
# 2  1996-04-03  47113
# 3  1996-04-08  47124
# 4  1996-04-09  47130

# %%
import psycopg2

# %%
# Establece los detalles de conexión
hostname = 'data-engineer-cluster.cyhh5bfevlmn.us-east-1.redshift.amazonaws.com'
port = '5439'
database = 'data-engineer-database'
username = 'catari_jose_coderhouse'
password = 'fdX921w2Cm'

# Establece la conexión
conn = psycopg2.connect(host=hostname, port=port, dbname=database, user=username, password=password)

# %%
cur = conn.cursor()

# %%
create_table_query = '''
    CREATE TABLE dato (
        fecha date,
        monto int,
    )
'''

# %%
cur.execute(create_table_query)
# Out:
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# <ipython-input-119-9a410b78ad16> in <cell line: 1>()
# ----> 1 cur.execute(create_table_query)
#
# SyntaxError: syntax error at or near ")"
# LINE 5:     )
#             ^

# %%
conn.commit()

# %%
cur.close()
conn.close()
